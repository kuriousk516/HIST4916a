# %%
# !pip install lxml
# Out:
# ...
#      |████████████████████████████████| 5.5 MB 4.4 MB/s eta 0:00:01
# ...

# %%
# !pip install beautifulsoup4
# Out:
# ...
#      |████████████████████████████████| 115 kB 3.9 MB/s eta 0:00:01
# ...

# %%
import requests

# %%
url = "https://www.historymuseum.ca/collections/search-results/?q=Ottawa&per_page=500&view=list"

response = requests.get(url)

data = response.text

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(data, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="search-results" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Search the Collections | Canadian Museum of History
#   </title>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://www.historymuseum.ca/collections/xmlrpc.php" rel="pingback"/>
#   <link href="https://www.historymuseum.ca/collections/wp-content/themes/collection-search/_images/favicons/apple-touch-icon.png?v=jw69Lm5BEG" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://www.historymuseum.ca/collections/wp-content/themes/collection-search/_images/favicons/favicon-32x32.png?v=jw69Lm5BEG" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://www.historymuseum.ca/collections/wp-content/themes/collection-search/_images/favicons/favicon-16x16.png?v=jw69Lm5BEG" rel="icon" sizes="16x16" type="image/png"/>
# ...

# %%
links = soup.find_all('a')

for link in links: 
    print(link)
# Out:
# <a class="bypass-link" href="#main-content" id="bypass-main">
# 			Skip to main content		</a>
# <a class="main-logo" href="https://www.historymuseum.ca/">
# <img alt="Logo of the Canadian Museum of History" class="main-logo-image" height="44" src="https://www.historymuseum.ca/collections/wp-content/themes/collection-search/_images/cmh-main-logo-grey.svg" title="" width="300"/> </a>
# <a class="favourites-handle" href="https://www.historymuseum.ca/collections/favourites/">
# <span class="text">Favourites</span>
# <svg aria-hidden="true" class="icon">
# <title>Heart</title>
# <use xlink:href="#heart"></use>
# </svg>
# <div class="favourites-count">
# <span class="favourites-count-icon">0</span>
# <span class="favourites-count-text"> items in your favourites list.</span>
# </div>
# </a>
# <a href="https://www.historymuseum.ca/collections/favourites/">
# 				Favourites			</a>
# ...

# %%
for link in links:
    names = link.contents[0]
    fullLink = link.get('href', {'class': 'collection item-wrapper'})
    print(names)
    print(fullLink)
# Out:
# 			Skip to main content
# #main-content
#
#
# https://www.historymuseum.ca/
#
#
# https://www.historymuseum.ca/collections/favourites/
#
# 				Favourites
# https://www.historymuseum.ca/collections/favourites/
#
#
# #nogo
#
# 		All Favourites
# https://www.historymuseum.ca/collections/favourites/
# Browse the collection
# https://www.historymuseum.ca/collections/search-results/
# Home
# https://www.historymuseum.ca/collections
#
# 	Français
# https://www.museedelhistoire.ca/collections/resultats-de-recherche/?q=Ottawa&per_page=500&view=list
# 25
# /collections/search-results/?q=Ottawa&per_page=25&view=list&page_num=1
# 50
# /collections/search-results/?q=Ottawa&per_page=50&view=list&page_num=1
# 100
# /collections/search-results/?q=Ottawa&per_page=100&view=list&page_num=1
# 200
# /collections/search-results/?q=Ottawa&per_page=200&view=list&page_num=1
#
#
# #media-filter
# Image Only
# /collections/search-results/?q=Ottawa&per_page=500&view=list&media=images
# Show All Media
# ...

# %%
import csv

f = csv.writer(open("histmuse.csv", "w"))
f.writerow(["Artifacts", "Link"])

links = soup.find_all('a')
for links in links:
    names = link.contents[0]
    fullLink = link.get('href')
    print(names)
    print(fullLink)
    f.writerow([names, fullLink])
# Out:
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# ...

# %%
import csv

f = csv.writer(open("histmuse.csv", "w"))
f.writerow(["Name", "Link"])

links = soup.find_all('a')
for links in links:
    names = link.contents[0]
    fullLink = link.get('href')
    # print(names)
    # print(fullLink)
    f.writerow([names, fullLink])

# %%
import csv

f = csv.writer(open("histmuse.csv", "w"))
f.writerow(["Name", "Link"])

links = soup.find_all('a')
for links in links:
    names = link.contents[0]
    fullLink = link.get('href')
    print(names)
    print(fullLink)
    f.writerow([names, fullLink])
# Out:
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# ...

# %%
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=865e399732d2428090d8825e55cf1606f13290bf480709ce6f121f4939600b3b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %%
# !pip install lxml
# Out:
# ...
#      |████████████████████████████████| 5.5 MB 4.5 MB/s eta 0:00:01
# ...

# %%
# !pip install beautifulsoup4
# Out:
# ...
#      |████████████████████████████████| 115 kB 4.1 MB/s eta 0:00:01
# ...

# %%
import requests

# %%
url = "https://www.historymuseum.ca/collections/search-results/?q=Ottawa&per_page=500&view=list"

response = requests.get(url)

data = response.text

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(data, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="search-results" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Search the Collections | Canadian Museum of History
#   </title>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://www.historymuseum.ca/collections/xmlrpc.php" rel="pingback"/>
#   <link href="https://www.historymuseum.ca/collections/wp-content/themes/collection-search/_images/favicons/apple-touch-icon.png?v=jw69Lm5BEG" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://www.historymuseum.ca/collections/wp-content/themes/collection-search/_images/favicons/favicon-32x32.png?v=jw69Lm5BEG" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://www.historymuseum.ca/collections/wp-content/themes/collection-search/_images/favicons/favicon-16x16.png?v=jw69Lm5BEG" rel="icon" sizes="16x16" type="image/png"/>
# ...

# %%
links = soup.find_all('a')

for link in links: 
    print(link)
# Out:
# <a class="bypass-link" href="#main-content" id="bypass-main">
# 			Skip to main content		</a>
# <a class="main-logo" href="https://www.historymuseum.ca/">
# <img alt="Logo of the Canadian Museum of History" class="main-logo-image" height="44" src="https://www.historymuseum.ca/collections/wp-content/themes/collection-search/_images/cmh-main-logo-grey.svg" title="" width="300"/> </a>
# <a class="favourites-handle" href="https://www.historymuseum.ca/collections/favourites/">
# <span class="text">Favourites</span>
# <svg aria-hidden="true" class="icon">
# <title>Heart</title>
# <use xlink:href="#heart"></use>
# </svg>
# <div class="favourites-count">
# <span class="favourites-count-icon">0</span>
# <span class="favourites-count-text"> items in your favourites list.</span>
# </div>
# </a>
# <a href="https://www.historymuseum.ca/collections/favourites/">
# 				Favourites			</a>
# ...

# %%
for link in links:
    names = link.contents[0]
    fullLink = link.get('href', {'class': 'collection-item-wrapper'})
    print(names)
    print(fullLink)
# Out:
# 			Skip to main content
# #main-content
#
#
# https://www.historymuseum.ca/
#
#
# https://www.historymuseum.ca/collections/favourites/
#
# 				Favourites
# https://www.historymuseum.ca/collections/favourites/
#
#
# #nogo
#
# 		All Favourites
# https://www.historymuseum.ca/collections/favourites/
# Browse the collection
# https://www.historymuseum.ca/collections/search-results/
# Home
# https://www.historymuseum.ca/collections
#
# 	Français
# https://www.museedelhistoire.ca/collections/resultats-de-recherche/?q=Ottawa&per_page=500&view=list
# 25
# /collections/search-results/?q=Ottawa&per_page=25&view=list&page_num=1
# 50
# /collections/search-results/?q=Ottawa&per_page=50&view=list&page_num=1
# 100
# /collections/search-results/?q=Ottawa&per_page=100&view=list&page_num=1
# 200
# /collections/search-results/?q=Ottawa&per_page=200&view=list&page_num=1
#
#
# #media-filter
# Image Only
# /collections/search-results/?q=Ottawa&per_page=500&view=list&media=images
# Show All Media
# ...

# %%
import csv

f = csv.writer(open("histmuse.csv", "w"))
f.writerow(["Names", "Link"])

links = soup.find_all('a')
for links in links:
    names = link.contents[0]
    fullLink = link.get('href')
    print(names)
    print(fullLink)
    f.writerow([names, fullLink])
# Out:
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# https://www.historymuseum.ca/about/copyright-and-permissions/
# Copyright
# ...

# %%
import csv

f = csv.writer(open("histmuse.csv", "w"))
f.writerow(["Name", "Link"])

links = soup.find_all('a')
for link in links:
    names = link.contents[0]
    fullLink = link.get('href')
    print(names)
    print(fullLink)
    f.writerow([names, fullLink])
# Out:
# 			Skip to main content
# #main-content
#
#
# https://www.historymuseum.ca/
#
#
# https://www.historymuseum.ca/collections/favourites/
#
# 				Favourites
# https://www.historymuseum.ca/collections/favourites/
#
#
# #nogo
#
# 		All Favourites
# https://www.historymuseum.ca/collections/favourites/
# Browse the collection
# https://www.historymuseum.ca/collections/search-results/
# Home
# https://www.historymuseum.ca/collections
#
# 	Français
# https://www.museedelhistoire.ca/collections/resultats-de-recherche/?q=Ottawa&per_page=500&view=list
# 25
# /collections/search-results/?q=Ottawa&per_page=25&view=list&page_num=1
# 50
# /collections/search-results/?q=Ottawa&per_page=50&view=list&page_num=1
# 100
# /collections/search-results/?q=Ottawa&per_page=100&view=list&page_num=1
# 200
# /collections/search-results/?q=Ottawa&per_page=200&view=list&page_num=1
#
#
# #media-filter
# Image Only
# /collections/search-results/?q=Ottawa&per_page=500&view=list&media=images
# Show All Media
# ...

# %%
# !wget -i work_you_bastard.text --no-parent -nd -w 2 --limit-rate=100k
# Out:
# --2021-04-09 18:08:56--  https://www.historymuseum.ca/collections/artifact/1337564/
# Resolving www.historymuseum.ca (www.historymuseum.ca)... 99.84.253.121, 99.84.253.106, 99.84.253.108, ...
# Connecting to www.historymuseum.ca (www.historymuseum.ca)|99.84.253.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [  <=>               ]  34.73K   156KB/s    in 0.2s
#
# 2021-04-09 18:08:57 (156 KB/s) - ‘index.html’ saved [35566]
#
# --2021-04-09 18:08:59--  https://www.historymuseum.ca/collections/artifact/2359060/
# Reusing existing connection to www.historymuseum.ca:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.1’
#
# index.html.1            [  <=>               ]  35.65K   138KB/s    in 0.3s
#
# 2021-04-09 18:08:59 (138 KB/s) - ‘index.html.1’ saved [36502]
#
# ...

# %%
spans = soup.find_all('span', {'class': 'collection-item-metadata artifact-number'})
for span in spans:
    print(span)
# Out:
# <span class="collection-item-metadata artifact-number">2001.145.1</span>
# <span class="collection-item-metadata artifact-number">2013.4.18</span>
# <span class="collection-item-metadata artifact-number">2000.194.1.6</span>
# <span class="collection-item-metadata artifact-number">D-8116.84</span>
# <span class="collection-item-metadata artifact-number">D-8116.43</span>
# <span class="collection-item-metadata artifact-number">D-8116.58</span>
# <span class="collection-item-metadata artifact-number">D-8116.60</span>
# <span class="collection-item-metadata artifact-number">D-8116.56</span>
# <span class="collection-item-metadata artifact-number">D-8116.31</span>
# <span class="collection-item-metadata artifact-number">D-8116.33</span>
# <span class="collection-item-metadata artifact-number">D-8116.32</span>
# <span class="collection-item-metadata artifact-number">D-8116.39</span>
# <span class="collection-item-metadata artifact-number">D-8116.40</span>
# ...

# %%
trs = soup.find_all('img', {'class': 'collection-item-image'})
for tr in trs:
    print(tr)
# Out:
# <img alt="painting, Madonna and Child Over Ottawa" class="collection-item-image" src="https://www.historymuseum.ca/collections/wp-content/uploads/artifacts/860/3016860/3320-2131-4528-029-167x255.jpg"/>
# <img alt="vase" class="collection-item-image" src="https://www.historymuseum.ca/collections/wp-content/uploads/artifacts/974/5418974/IMG2014-0097-0017-Dm-204x255.jpg"/>
# <img alt="pennant" class="collection-item-image" src="https://www.historymuseum.ca/collections/wp-content/uploads/artifacts/510/3001510/1271-3161-1338-006-300x200.jpg"/>
# <img alt="stand" class="collection-item-image" src="https://www.historymuseum.ca/collections/wp-content/uploads/artifacts/91/391091/3112-1032-1163-002.base-170x255.jpg"/>
# <img alt="table" class="collection-item-image" src="https://www.historymuseum.ca/collections/wp-content/uploads/artifacts/896/100896/3112-1032-1163-050.base-300x200.jpg"/>
# ...

# %%
spans = soup.find_all('benin': {'collection-artifact'})
for span in spans:
    print(span)
# Out:
#   File "<ipython-input-14-c632b5e8015f>", line 1
#     spans = soup.find_all('benin': {'collection-artifact'})
#                                  ^
# SyntaxError: invalid syntax

# %%
spans = soup.find_all('benin', {'class': 'artifact'})
for span in spans:
    print(span)

# %%
spans = soup.find_all('span', {'class': 'benin'})
for span in spans:
    print(span)

# %%
# !wget -i URL.text --no-parent -nd -w 2 --limit-rate=100k
# Out:
# --2021-04-09 18:20:23--  https://www.historymuseum.ca/collections/artifact/1337564/
# Resolving www.historymuseum.ca (www.historymuseum.ca)... 99.84.253.108, 99.84.253.23, 99.84.253.121, ...
# Connecting to www.historymuseum.ca (www.historymuseum.ca)|99.84.253.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.21’
#
# index.html.21           [  <=>               ]  34.73K   145KB/s    in 0.2s
#
# 2021-04-09 18:20:24 (145 KB/s) - ‘index.html.21’ saved [35566]
#
# --2021-04-09 18:20:26--  https://www.historymuseum.ca/collections/artifact/2359060/
# Reusing existing connection to www.historymuseum.ca:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.22’
#
# index.html.22           [  <=>               ]  35.65K   153KB/s    in 0.2s
#
# 2021-04-09 18:20:27 (153 KB/s) - ‘index.html.22’ saved [36502]
#
# ...

# %%
# !wget --help
# Out:
# GNU Wget 1.19.4, a non-interactive network retriever.
# Usage: wget [OPTION]... [URL]...
#
# Mandatory arguments to long options are mandatory for short options too.
#
# Startup:
#   -V,  --version                   display the version of Wget and exit
#   -h,  --help                      print this help
#   -b,  --background                go to background after startup
#   -e,  --execute=COMMAND           execute a `.wgetrc'-style command
#
# Logging and input file:
#   -o,  --output-file=FILE          log messages to FILE
#   -a,  --append-output=FILE        append messages to FILE
#   -d,  --debug                     print lots of debugging information
#   -q,  --quiet                     quiet (no output)
#   -v,  --verbose                   be verbose (this is the default)
#   -nv, --no-verbose                turn off verboseness, without being quiet
#        --report-speed=TYPE         output bandwidth as TYPE.  TYPE can be bits
# ...

# %%
spans = soup.find_all('span', {'class': 'collection-item-metadata artifact-number'})
for span in spans:
    print(span)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b0c7348ca389> in <module>
# ----> 1 spans = soup.find_all('span', {'class': 'collection-item-metadata artifact-number'})
#       2 for span in spans:
#       3     print(span)
#
# NameError: name 'soup' is not defined

# %%
# !pip install beautifulsoup4
